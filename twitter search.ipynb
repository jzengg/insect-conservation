# %%
import json
import time
import math
import os
from collections import defaultdict
from statistics import mean, stdev
from csv import DictWriter
from operator import itemgetter, attrgetter

from searchtweets import ResultStream, gen_rule_payload, load_credentials, collect_results
import pandas as pd
import pycld2 as cld2
from textblob import TextBlob
from transformers import pipeline
import warnings
warnings.filterwarnings('ignore')

TWITTER_RESULTS_FIELD_NAMES = [
    "user_tweets_count", 
    "user_friends_count", 
    "user_followers_count", 
    "retweet_count", 
    "reply_count", 
    "quote_count", 
    "favorite_count", 
    "family",
]
TWITTER_DUMP_FIELD_NAMES = [
    "family",
    "serialized_tweets",
]

FAMILY_NAMES = "data/rainford_family_key.txt"
CLEANED_FAMILIES = "data/families.txt"
TWITTER_RESULTS = "data/twitter_results.csv"
TWITTER_DUMP = "data/twitter_results_tweet_dump.csv"

# %%
# read in family names file and clean up incomplete lines
families = []
incomplete = []
not_idae = []
with open(FAMILY_NAMES, 'r') as file:
    for line in file:
        names = line.split()
        if len(names) < 3:
            incomplete.append(names)
        family = names[1]
        if not family.endswith('idae'):
            not_idae.append(family)
        families.append(family)
not_idae
# Out:
# ['Archaeognatha',
#  'Projapygoidea',
#  'Grylloblat',
#  'Aleyrodoidea',
#  'Aphidoidea',
#  'Coccoidea',
#  'Phylloxeroidea',
#  'Psylloidea',
#  'Mantophasm',
#  'Strepsipte',
#  'Zoraptera']

# %%
# Clean out bad data using wrong family name and remove dupe
incorrect = [pair[1] for pair in incomplete]
incorrect.remove('Zoraptera')
dump = pd.read_csv(TWITTER_DUMP)
corrected_dump = dump[~dump.family.isin(incorrect)]
corrected_dump = corrected_dump.drop_duplicates()
len(corrected_dump)
corrected_dump.to_csv("corrected_twitter_results_tweet_dump.csv")

# %%
# Stream in a row of tweet data
def add_row(row, header):
    with open(TWITTER_RESULTS, 'a') as write_obj:
        writer = DictWriter(write_obj, fieldnames=TWITTER_RESULTS_FIELD_NAMES)
        if header:
            writer.writeheader()
        writer.writerow(row)

# Stream in a row of serialized raw tweet data
def add_dump_row(row, header):
    with open(TWITTER_DUMP, 'a') as write_obj:
        writer = DictWriter(write_obj, fieldnames=TWITTER_DUMP_FIELD_NAMES)
        if header:
            writer.writeheader()
        writer.writerow(row)

# %%
# Clean up tweets and the serialized raw tweets
os.remove(TWITTER_RESULTS)
os.remove(TWITTER_DUMP)

# %%
# Aggregate total tweet count using the raw tweet results
family_tweet_count = {}

dump = pd.read_csv(CORRECTED_TWITTER_DUMP)
for index, row in dump.iterrows():
    tweets = json.loads(row.serialized_tweets)
    family_tweet_count[row.family] = len(tweets)
family_tweet_count

# %%
# Copy over data from raw tweets to the actual tweets csv
corrected_results = pd.read_csv(CORRECTED_TWITTER_RESULTS)
corrected_results['tweet_count'] = corrected_results['family'].map(family_tweet_count)
corrected_results

# %%
# Calculate a tweet's sentiment using transformers pipeline
nlp_sentiment = pipeline("sentiment-analysis")
def get_tf_sentiment_polarity(text):
    tf = nlp_sentiment(text)[0]
    score = tf['score']
    if tf['label'] == 'NEGATIVE':
        score *= -1
    return score
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=230.0, style=ProgressStyle(description_…

# %%
# Get sentiment data for each tweet, only using tweets that have been identified as English using the cld2 library
# Also get counts for how many tweets in each country and language
family_tweet_sentiments = {}
tweet_tf_sentiments = []
tweet_sentiments = []
language_counts = defaultdict(int)
place_counts = defaultdict(int)

dump = pd.read_csv(TWITTER_DUMP)
tweets_with_score_and_family = []
for index, row in dump.iterrows():
    print('Starting index {} / {}'.format(index, len(dump)))
    tweets = json.loads(row.serialized_tweets)
    tweet_polarities = []
    tweet_tf_polarities = []
    for tweet in tweets:
        place = tweet['place']
#         if place is not None:
#             place_counts[place['country_code']] += 1
#         else:
#             place_counts['no_location'] += 1
        text = tweet['text']
        if tweet['truncated']:
            text = tweet['extended_tweet']['full_text']
        is_reliable, text_bytes_found, language_details = cld2.detect(text)
        
        if is_reliable:
            language = language_details[0][1]
            language_counts[language] += 1
            if language == 'en':
                # calculate both the textblob sentiment as well as the sentiment from transformers pipeline
                # for comparison
                text_blob = TextBlob(text)
                polarity = text_blob.sentiment.polarity
                tf_polarity = get_tf_sentiment_polarity(text)
                data = {'text': text, 'transformers_score': tf_polarity, 'textblob_score': polarity,'family': row.family}
                tweets_with_score_and_family.append(data)
#                 tweet_tf_polarities.append(tf_polarity)
#                 tweet_tf_sentiments.append({'text': text, 'score': tf_polarity})
#                 tweet_sentiments.append({'text': text, 'score': polarity})
#                 tweet_polarities.append(polarity)
        else:
            language_counts['could_not_detect_language'] += 1
#     if not tweet_polarities:
#         continue
    # get mean and standard deviation of tweet polarities for all tweets in a family
#     num_tweets_with_sentiment = len(tweet_polarities)
#     mean_polarity = mean(tweet_polarities)
#     tf_mean_polarity = mean(tweet_tf_polarities)
#     standard_deviation_polarity = 0 if len(tweet_polarities) < 2 else stdev(tweet_polarities)
#     tf_sd_polarity = 0 if len(tweet_tf_polarities) < 2 else stdev(tweet_tf_polarities)
#     family_tweet_sentiments[row.family] = (mean_polarity, standard_deviation_polarity, num_tweets_with_sentiment, tf_mean_polarity, tf_sd_polarity)

tweets_with_score_and_family_df = pd.DataFrame(tweets_with_score_and_family)
tweets_with_score_and_family_df.to_csv('tweets_with_score_and_family.csv')
# language_counts = [{'count': count, 'language': language} for language, count in language_counts.items()]
# language_counts = sorted(language_counts, key=itemgetter('count'), reverse=True)
# language_counts_df = pd.DataFrame(language_counts)
# language_counts_df

# place_counts = [{'count': count, 'location': location} for location, count in place_counts.items()]
# place_counts = sorted(place_counts, key=itemgetter('count'), reverse=True)
# place_counts_df = pd.DataFrame(place_counts)
# Save results to CSV
# place_counts_df.to_csv('tweet_location_counts.csv')
# language_counts_df.to_csv('tweet_language_counts.csv')
# Out:
# Starting index 0 / 875
# Starting index 1 / 875
# Starting index 2 / 875
# Starting index 3 / 875
# Starting index 4 / 875
# Starting index 5 / 875
# Starting index 6 / 875
# Starting index 7 / 875
# Starting index 8 / 875
# Starting index 9 / 875
# Starting index 10 / 875
# Starting index 11 / 875
# Starting index 12 / 875
# Starting index 13 / 875
# Starting index 14 / 875
# Starting index 15 / 875
# Starting index 16 / 875
# Starting index 17 / 875
# Starting index 18 / 875
# Starting index 19 / 875
# Starting index 20 / 875
# Starting index 21 / 875
# Starting index 22 / 875
# Starting index 23 / 875
# Starting index 24 / 875
# Starting index 25 / 875
# Starting index 26 / 875
# Starting index 27 / 875
# Starting index 28 / 875
# Starting index 29 / 875
# Starting index 30 / 875
# Starting index 31 / 875
# Starting index 32 / 875
# Starting index 33 / 875
# Starting index 34 / 875
# Starting index 35 / 875
# Starting index 36 / 875
# Starting index 37 / 875
# Starting index 38 / 875
# Starting index 39 / 875
# Starting index 40 / 875
# Starting index 41 / 875
# Starting index 42 / 875
# Starting index 43 / 875
# Starting index 44 / 875
# Starting index 45 / 875
# Starting index 46 / 875
# Starting index 47 / 875
# Starting index 48 / 875
# Starting index 49 / 875
# Starting index 50 / 875
# Starting index 51 / 875
# Starting index 52 / 875
# Starting index 53 / 875
# Starting index 54 / 875
# Starting index 55 / 875
# Starting index 56 / 875
# Starting index 57 / 875
# Starting index 58 / 875
# Starting index 59 / 875
# Starting index 60 / 875
# Starting index 61 / 875
# Starting index 62 / 875
# Starting index 63 / 875
# Starting index 64 / 875
# Starting index 65 / 875
# Starting index 66 / 875
# Starting index 67 / 875
# Starting index 68 / 875
# Starting index 69 / 875
# Starting index 70 / 875
# Starting index 71 / 875
# Starting index 72 / 875
# Starting index 73 / 875
# Starting index 74 / 875
# Starting index 75 / 875
# Starting index 76 / 875
# Starting index 77 / 875
# Starting index 78 / 875
# Starting index 79 / 875
# Starting index 80 / 875
# Starting index 81 / 875
# Starting index 82 / 875
# Starting index 83 / 875
# Starting index 84 / 875
# Starting index 85 / 875
# Starting index 86 / 875
# Starting index 87 / 875
# Starting index 88 / 875
# Starting index 89 / 875
# Starting index 90 / 875
# Starting index 91 / 875
# Starting index 92 / 875
# Starting index 93 / 875
# Starting index 94 / 875
# Starting index 95 / 875
# Starting index 96 / 875
# Starting index 97 / 875
# Starting index 98 / 875
# Starting index 99 / 875
# Starting index 100 / 875
# Starting index 101 / 875
# Starting index 102 / 875
# Starting index 103 / 875
# Starting index 104 / 875
# Starting index 105 / 875
# Starting index 106 / 875
# Starting index 107 / 875
# Starting index 108 / 875
# Starting index 109 / 875
# Starting index 110 / 875
# Starting index 111 / 875
# Starting index 112 / 875
# Starting index 113 / 875
# Starting index 114 / 875
# Starting index 115 / 875
# Starting index 116 / 875
# Starting index 117 / 875
# Starting index 118 / 875
# Starting index 119 / 875
# Starting index 120 / 875
# Starting index 121 / 875
# Starting index 122 / 875
# Starting index 123 / 875
# Starting index 124 / 875
# Starting index 125 / 875
# Starting index 126 / 875
# Starting index 127 / 875
# Starting index 128 / 875
# Starting index 129 / 875
# Starting index 130 / 875
# Starting index 131 / 875
# Starting index 132 / 875
# Starting index 133 / 875
# Starting index 134 / 875
# Starting index 135 / 875
# Starting index 136 / 875
# Starting index 137 / 875
# Starting index 138 / 875
# Starting index 139 / 875
# Starting index 140 / 875
# Starting index 141 / 875
# Starting index 142 / 875
# Starting index 143 / 875
# Starting index 144 / 875
# Starting index 145 / 875
# Starting index 146 / 875
# Starting index 147 / 875
# Starting index 148 / 875
# Starting index 149 / 875
# Starting index 150 / 875
# Starting index 151 / 875
# Starting index 152 / 875
# Starting index 153 / 875
# Starting index 154 / 875
# Starting index 155 / 875
# Starting index 156 / 875
# Starting index 157 / 875
# Starting index 158 / 875
# Starting index 159 / 875
# Starting index 160 / 875
# Starting index 161 / 875
# Starting index 162 / 875
# Starting index 163 / 875
# Starting index 164 / 875
# Starting index 165 / 875
# Starting index 166 / 875
# Starting index 167 / 875
# Starting index 168 / 875
# Starting index 169 / 875
# Starting index 170 / 875
# Starting index 171 / 875
# Starting index 172 / 875
# Starting index 173 / 875
# Starting index 174 / 875
# Starting index 175 / 875
# Starting index 176 / 875
# Starting index 177 / 875
# Starting index 178 / 875
# Starting index 179 / 875
# Starting index 180 / 875
# Starting index 181 / 875
# Starting index 182 / 875
# Starting index 183 / 875
# Starting index 184 / 875
# Starting index 185 / 875
# Starting index 186 / 875
# Starting index 187 / 875
# Starting index 188 / 875
# Starting index 189 / 875
# Starting index 190 / 875
# Starting index 191 / 875
# Starting index 192 / 875
# Starting index 193 / 875
# Starting index 194 / 875
# Starting index 195 / 875
# Starting index 196 / 875
# Starting index 197 / 875
# Starting index 198 / 875
# Starting index 199 / 875
# Starting index 200 / 875
# Starting index 201 / 875
# Starting index 202 / 875
# Starting index 203 / 875
# Starting index 204 / 875
# Starting index 205 / 875
# Starting index 206 / 875
# Starting index 207 / 875
# Starting index 208 / 875
# Starting index 209 / 875
# Starting index 210 / 875
# Starting index 211 / 875
# Starting index 212 / 875
# Starting index 213 / 875
# Starting index 214 / 875
# Starting index 215 / 875
# Starting index 216 / 875
# Starting index 217 / 875
# Starting index 218 / 875
# Starting index 219 / 875
# Starting index 220 / 875
# Starting index 221 / 875
# Starting index 222 / 875
# Starting index 223 / 875
# Starting index 224 / 875
# Starting index 225 / 875
# Starting index 226 / 875
# Starting index 227 / 875
# Starting index 228 / 875
# Starting index 229 / 875
# Starting index 230 / 875
# Starting index 231 / 875
# Starting index 232 / 875
# Starting index 233 / 875
# Starting index 234 / 875
# Starting index 235 / 875
# Starting index 236 / 875
# Starting index 237 / 875
# Starting index 238 / 875
# Starting index 239 / 875
# Starting index 240 / 875
# Starting index 241 / 875
# Starting index 242 / 875
# Starting index 243 / 875
# Starting index 244 / 875
# Starting index 245 / 875
# Starting index 246 / 875
# Starting index 247 / 875
# Starting index 248 / 875
# Starting index 249 / 875
# Starting index 250 / 875
# Starting index 251 / 875
# Starting index 252 / 875
# Starting index 253 / 875
# Starting index 254 / 875
# Starting index 255 / 875
# Starting index 256 / 875
# Starting index 257 / 875
# Starting index 258 / 875
# Starting index 259 / 875
# Starting index 260 / 875
# Starting index 261 / 875
# Starting index 262 / 875
# Starting index 263 / 875
# Starting index 264 / 875
# Starting index 265 / 875
# Starting index 266 / 875
# Starting index 267 / 875
# Starting index 268 / 875
# Starting index 269 / 875
# Starting index 270 / 875
# Starting index 271 / 875
# Starting index 272 / 875
# Starting index 273 / 875
# Starting index 274 / 875
# Starting index 275 / 875
# Starting index 276 / 875
# Starting index 277 / 875
# Starting index 278 / 875
# Starting index 279 / 875
# Starting index 280 / 875
# Starting index 281 / 875
# Starting index 282 / 875
# Starting index 283 / 875
# Starting index 284 / 875
# Starting index 285 / 875
# Starting index 286 / 875
# Starting index 287 / 875
# Starting index 288 / 875
# Starting index 289 / 875
# Starting index 290 / 875
# Starting index 291 / 875
# Starting index 292 / 875
# Starting index 293 / 875
# Starting index 294 / 875
# Starting index 295 / 875
# Starting index 296 / 875
# Starting index 297 / 875
# Starting index 298 / 875
# Starting index 299 / 875
# Starting index 300 / 875
# Starting index 301 / 875
# Starting index 302 / 875
# Starting index 303 / 875
# Starting index 304 / 875
# Starting index 305 / 875
# Starting index 306 / 875
# Starting index 307 / 875
# Starting index 308 / 875
# Starting index 309 / 875
# Starting index 310 / 875
# Starting index 311 / 875
# Starting index 312 / 875
# Starting index 313 / 875
# Starting index 314 / 875
# Starting index 315 / 875
# Starting index 316 / 875
# Starting index 317 / 875
# Starting index 318 / 875
# Starting index 319 / 875
# Starting index 320 / 875
# Starting index 321 / 875
# Starting index 322 / 875
# Starting index 323 / 875
# Starting index 324 / 875
# Starting index 325 / 875
# Starting index 326 / 875
# Starting index 327 / 875
# Starting index 328 / 875
# Starting index 329 / 875
# Starting index 330 / 875
# Starting index 331 / 875
# Starting index 332 / 875
# Starting index 333 / 875
# Starting index 334 / 875
# Starting index 335 / 875
# Starting index 336 / 875
# Starting index 337 / 875
# Starting index 338 / 875
# Starting index 339 / 875
# Starting index 340 / 875
# Starting index 341 / 875
# Starting index 342 / 875
# Starting index 343 / 875
# Starting index 344 / 875
# Starting index 345 / 875
# Starting index 346 / 875
# Starting index 347 / 875
# Starting index 348 / 875
# Starting index 349 / 875
# Starting index 350 / 875
# Starting index 351 / 875
# Starting index 352 / 875
# Starting index 353 / 875
# Starting index 354 / 875
# Starting index 355 / 875
# Starting index 356 / 875
# Starting index 357 / 875
# Starting index 358 / 875
# Starting index 359 / 875
# Starting index 360 / 875
# Starting index 361 / 875
# Starting index 362 / 875
# Starting index 363 / 875
# Starting index 364 / 875
# Starting index 365 / 875
# Starting index 366 / 875
# Starting index 367 / 875
# Starting index 368 / 875
# Starting index 369 / 875
# Starting index 370 / 875
# Starting index 371 / 875
# Starting index 372 / 875
# Starting index 373 / 875
# Starting index 374 / 875
# Starting index 375 / 875
# Starting index 376 / 875
# Starting index 377 / 875
# Starting index 378 / 875
# Starting index 379 / 875
# Starting index 380 / 875
# Starting index 381 / 875
# Starting index 382 / 875
# Starting index 383 / 875
# Starting index 384 / 875
# Starting index 385 / 875
# Starting index 386 / 875
# Starting index 387 / 875
# Starting index 388 / 875
# Starting index 389 / 875
# Starting index 390 / 875
# Starting index 391 / 875
# Starting index 392 / 875
# Starting index 393 / 875
# Starting index 394 / 875
# Starting index 395 / 875
# Starting index 396 / 875
# Starting index 397 / 875
# Starting index 398 / 875
# Starting index 399 / 875
# Starting index 400 / 875
# Starting index 401 / 875
# Starting index 402 / 875
# Starting index 403 / 875
# Starting index 404 / 875
# Starting index 405 / 875
# Starting index 406 / 875
# Starting index 407 / 875
# Starting index 408 / 875
# Starting index 409 / 875
# Starting index 410 / 875
# Starting index 411 / 875
# Starting index 412 / 875
# Starting index 413 / 875
# Starting index 414 / 875
# Starting index 415 / 875
# Starting index 416 / 875
# Starting index 417 / 875
# Starting index 418 / 875
# Starting index 419 / 875
# Starting index 420 / 875
# Starting index 421 / 875
# Starting index 422 / 875
# Starting index 423 / 875
# Starting index 424 / 875
# Starting index 425 / 875
# Starting index 426 / 875
# Starting index 427 / 875
# Starting index 428 / 875
# Starting index 429 / 875
# Starting index 430 / 875
# Starting index 431 / 875
# Starting index 432 / 875
# Starting index 433 / 875
# Starting index 434 / 875
# Starting index 435 / 875
# Starting index 436 / 875
# Starting index 437 / 875
# Starting index 438 / 875
# Starting index 439 / 875
# Starting index 440 / 875
# Starting index 441 / 875
# Starting index 442 / 875
# Starting index 443 / 875
# Starting index 444 / 875
# Starting index 445 / 875
# Starting index 446 / 875
# Starting index 447 / 875
# Starting index 448 / 875
# Starting index 449 / 875
# Starting index 450 / 875
# Starting index 451 / 875
# Starting index 452 / 875
# Starting index 453 / 875
# Starting index 454 / 875
# Starting index 455 / 875
# Starting index 456 / 875
# Starting index 457 / 875
# Starting index 458 / 875
# Starting index 459 / 875
# Starting index 460 / 875
# Starting index 461 / 875
# Starting index 462 / 875
# Starting index 463 / 875
# Starting index 464 / 875
# Starting index 465 / 875
# Starting index 466 / 875
# Starting index 467 / 875
# Starting index 468 / 875
# Starting index 469 / 875
# Starting index 470 / 875
# Starting index 471 / 875
# Starting index 472 / 875
# Starting index 473 / 875
# Starting index 474 / 875
# Starting index 475 / 875
# Starting index 476 / 875
# Starting index 477 / 875
# Starting index 478 / 875
# Starting index 479 / 875
# Starting index 480 / 875
# Starting index 481 / 875
# Starting index 482 / 875
# Starting index 483 / 875
# Starting index 484 / 875
# Starting index 485 / 875
# Starting index 486 / 875
# Starting index 487 / 875
# Starting index 488 / 875
# Starting index 489 / 875
# Starting index 490 / 875
# Starting index 491 / 875
# Starting index 492 / 875
# Starting index 493 / 875
# Starting index 494 / 875
# Starting index 495 / 875
# Starting index 496 / 875
# Starting index 497 / 875
# Starting index 498 / 875
# Starting index 499 / 875
# Starting index 500 / 875
# Starting index 501 / 875
# Starting index 502 / 875
# Starting index 503 / 875
# Starting index 504 / 875
# Starting index 505 / 875
# Starting index 506 / 875
# Starting index 507 / 875
# Starting index 508 / 875
# Starting index 509 / 875
# Starting index 510 / 875
# Starting index 511 / 875
# Starting index 512 / 875
# Starting index 513 / 875
# Starting index 514 / 875
# Starting index 515 / 875
# Starting index 516 / 875
# Starting index 517 / 875
# Starting index 518 / 875
# Starting index 519 / 875
# Starting index 520 / 875
# Starting index 521 / 875
# Starting index 522 / 875
# Starting index 523 / 875
# Starting index 524 / 875
# Starting index 525 / 875
# Starting index 526 / 875
# Starting index 527 / 875
# Starting index 528 / 875
# Starting index 529 / 875
# Starting index 530 / 875
# Starting index 531 / 875
# Starting index 532 / 875
# Starting index 533 / 875
# Starting index 534 / 875
# Starting index 535 / 875
# Starting index 536 / 875
# Starting index 537 / 875
# Starting index 538 / 875
# Starting index 539 / 875
# Starting index 540 / 875
# Starting index 541 / 875
# Starting index 542 / 875
# Starting index 543 / 875
# Starting index 544 / 875
# Starting index 545 / 875
# Starting index 546 / 875
# Starting index 547 / 875
# Starting index 548 / 875
# Starting index 549 / 875
# Starting index 550 / 875
# Starting index 551 / 875
# Starting index 552 / 875
# Starting index 553 / 875
# Starting index 554 / 875
# Starting index 555 / 875
# Starting index 556 / 875
# Starting index 557 / 875
# Starting index 558 / 875
# Starting index 559 / 875
# Starting index 560 / 875
# Starting index 561 / 875
# Starting index 562 / 875
# Starting index 563 / 875
# Starting index 564 / 875
# Starting index 565 / 875
# Starting index 566 / 875
# Starting index 567 / 875
# Starting index 568 / 875
# Starting index 569 / 875
# Starting index 570 / 875
# Starting index 571 / 875
# Starting index 572 / 875
# Starting index 573 / 875
# Starting index 574 / 875
# Starting index 575 / 875
# Starting index 576 / 875
# Starting index 577 / 875
# Starting index 578 / 875
# Starting index 579 / 875
# Starting index 580 / 875
# Starting index 581 / 875
# Starting index 582 / 875
# Starting index 583 / 875
# Starting index 584 / 875
# Starting index 585 / 875
# Starting index 586 / 875
# Starting index 587 / 875
# Starting index 588 / 875
# Starting index 589 / 875
# Starting index 590 / 875
# Starting index 591 / 875
# Starting index 592 / 875
# Starting index 593 / 875
# Starting index 594 / 875
# Starting index 595 / 875
# Starting index 596 / 875
# Starting index 597 / 875
# Starting index 598 / 875
# Starting index 599 / 875
# Starting index 600 / 875
# Starting index 601 / 875
# Starting index 602 / 875
# Starting index 603 / 875
# Starting index 604 / 875
# Starting index 605 / 875
# Starting index 606 / 875
# Starting index 607 / 875
# Starting index 608 / 875
# Starting index 609 / 875
# Starting index 610 / 875
# Starting index 611 / 875
# Starting index 612 / 875
# Starting index 613 / 875
# Starting index 614 / 875
# Starting index 615 / 875
# Starting index 616 / 875
# Starting index 617 / 875
# Starting index 618 / 875
# Starting index 619 / 875
# Starting index 620 / 875
# Starting index 621 / 875
# Starting index 622 / 875
# Starting index 623 / 875
# Starting index 624 / 875
# Starting index 625 / 875
# Starting index 626 / 875
# Starting index 627 / 875
# Starting index 628 / 875
# Starting index 629 / 875
# Starting index 630 / 875
# Starting index 631 / 875
# Starting index 632 / 875
# Starting index 633 / 875
# Starting index 634 / 875
# Starting index 635 / 875
# Starting index 636 / 875
# Starting index 637 / 875
# Starting index 638 / 875
# Starting index 639 / 875
# Starting index 640 / 875
# Starting index 641 / 875
# Starting index 642 / 875
# Starting index 643 / 875
# Starting index 644 / 875
# Starting index 645 / 875
# Starting index 646 / 875
# Starting index 647 / 875
# Starting index 648 / 875
# Starting index 649 / 875
# Starting index 650 / 875
# Starting index 651 / 875
# Starting index 652 / 875
# Starting index 653 / 875
# Starting index 654 / 875
# Starting index 655 / 875
# Starting index 656 / 875
# Starting index 657 / 875
# Starting index 658 / 875
# Starting index 659 / 875
# Starting index 660 / 875
# Starting index 661 / 875
# Starting index 662 / 875
# Starting index 663 / 875
# Starting index 664 / 875
# Starting index 665 / 875
# Starting index 666 / 875
# Starting index 667 / 875
# Starting index 668 / 875
# Starting index 669 / 875
# Starting index 670 / 875
# Starting index 671 / 875
# Starting index 672 / 875
# Starting index 673 / 875
# Starting index 674 / 875
# Starting index 675 / 875
# Starting index 676 / 875
# Starting index 677 / 875
# Starting index 678 / 875
# Starting index 679 / 875
# Starting index 680 / 875
# Starting index 681 / 875
# Starting index 682 / 875
# Starting index 683 / 875
# Starting index 684 / 875
# Starting index 685 / 875
# Starting index 686 / 875
# Starting index 687 / 875
# Starting index 688 / 875
# Starting index 689 / 875
# Starting index 690 / 875
# Starting index 691 / 875
# Starting index 692 / 875
# Starting index 693 / 875
# Starting index 694 / 875
# Starting index 695 / 875
# Starting index 696 / 875
# Starting index 697 / 875
# Starting index 698 / 875
# Starting index 699 / 875
# Starting index 700 / 875
# Starting index 701 / 875
# Starting index 702 / 875
# Starting index 703 / 875
# Starting index 704 / 875
# Starting index 705 / 875
# Starting index 706 / 875
# Starting index 707 / 875
# Starting index 708 / 875
# Starting index 709 / 875
# Starting index 710 / 875
# Starting index 711 / 875
# Starting index 712 / 875
# Starting index 713 / 875
# Starting index 714 / 875
# Starting index 715 / 875
# Starting index 716 / 875
# Starting index 717 / 875
# Starting index 718 / 875
# Starting index 719 / 875
# Starting index 720 / 875
# Starting index 721 / 875
# Starting index 722 / 875
# Starting index 723 / 875
# Starting index 724 / 875
# Starting index 725 / 875
# Starting index 726 / 875
# Starting index 727 / 875
# Starting index 728 / 875
# Starting index 729 / 875
# Starting index 730 / 875
# Starting index 731 / 875
# Starting index 732 / 875
# Starting index 733 / 875
# Starting index 734 / 875
# Starting index 735 / 875
# Starting index 736 / 875
# Starting index 737 / 875
# Starting index 738 / 875
# Starting index 739 / 875
# Starting index 740 / 875
# Starting index 741 / 875
# Starting index 742 / 875
# Starting index 743 / 875
# Starting index 744 / 875
# Starting index 745 / 875
# Starting index 746 / 875
# Starting index 747 / 875
# Starting index 748 / 875
# Starting index 749 / 875
# Starting index 750 / 875
# Starting index 751 / 875
# Starting index 752 / 875
# Starting index 753 / 875
# Starting index 754 / 875
# Starting index 755 / 875
# Starting index 756 / 875
# Starting index 757 / 875
# Starting index 758 / 875
# Starting index 759 / 875
# Starting index 760 / 875
# Starting index 761 / 875
# Starting index 762 / 875
# Starting index 763 / 875
# Starting index 764 / 875
# Starting index 765 / 875
# Starting index 766 / 875
# Starting index 767 / 875
# Starting index 768 / 875
# Starting index 769 / 875
# Starting index 770 / 875
# Starting index 771 / 875
# Starting index 772 / 875
# Starting index 773 / 875
# Starting index 774 / 875
# Starting index 775 / 875
# Starting index 776 / 875
# Starting index 777 / 875
# Starting index 778 / 875
# Starting index 779 / 875
# Starting index 780 / 875
# Starting index 781 / 875
# Starting index 782 / 875
# Starting index 783 / 875
# Starting index 784 / 875
# Starting index 785 / 875
# Starting index 786 / 875
# Starting index 787 / 875
# Starting index 788 / 875
# Starting index 789 / 875
# Starting index 790 / 875
# Starting index 791 / 875
# Starting index 792 / 875
# Starting index 793 / 875
# Starting index 794 / 875
# Starting index 795 / 875
# Starting index 796 / 875
# Starting index 797 / 875
# Starting index 798 / 875
# Starting index 799 / 875
# Starting index 800 / 875
# Starting index 801 / 875
# Starting index 802 / 875
# Starting index 803 / 875
# Starting index 804 / 875
# Starting index 805 / 875
# Starting index 806 / 875
# Starting index 807 / 875
# Starting index 808 / 875
# Starting index 809 / 875
# Starting index 810 / 875
# Starting index 811 / 875
# Starting index 812 / 875
# Starting index 813 / 875
# Starting index 814 / 875
# Starting index 815 / 875
# Starting index 816 / 875
# Starting index 817 / 875
# Starting index 818 / 875
# Starting index 819 / 875
# Starting index 820 / 875
# Starting index 821 / 875
# Starting index 822 / 875
# Starting index 823 / 875
# Starting index 824 / 875
# Starting index 825 / 875
# Starting index 826 / 875
# Starting index 827 / 875
# Starting index 828 / 875
# Starting index 829 / 875
# Starting index 830 / 875
# Starting index 831 / 875
# Starting index 832 / 875
# Starting index 833 / 875
# Starting index 834 / 875
# Starting index 835 / 875
# Starting index 836 / 875
# Starting index 837 / 875
# Starting index 838 / 875
# Starting index 839 / 875
# Starting index 840 / 875
# Starting index 841 / 875
# Starting index 842 / 875
# Starting index 843 / 875
# Starting index 844 / 875
# Starting index 845 / 875
# Starting index 846 / 875
# Starting index 847 / 875
# Starting index 848 / 875
# Starting index 849 / 875
# Starting index 850 / 875
# Starting index 851 / 875
# Starting index 852 / 875
# Starting index 853 / 875
# Starting index 854 / 875
# Starting index 855 / 875
# Starting index 856 / 875
# Starting index 857 / 875
# Starting index 858 / 875
# Starting index 859 / 875
# Starting index 860 / 875
# Starting index 861 / 875
# Starting index 862 / 875
# Starting index 863 / 875
# Starting index 864 / 875
# Starting index 865 / 875
# Starting index 866 / 875
# Starting index 867 / 875
# Starting index 868 / 875
# Starting index 869 / 875
# Starting index 870 / 875
# Starting index 871 / 875
# Starting index 872 / 875
# Starting index 873 / 875
# Starting index 874 / 875

# %%
# Get top ten and bottom ten tweet text by sentiment
ordered_tweet_tf_sentiments = sorted(tweet_tf_sentiments, key=itemgetter('score'))
tf_sentiment_scores = [sentiment['score'] for sentiment in tweet_tf_sentiments]
tf_overall_mean = mean(tf_sentiment_scores)
tf_overall_sd = stdev(tf_sentiment_scores)
tf_bottom_ten = ordered_tweet_tf_sentiments[:20]
len(tf_sentiment_scores)
# tf_top_ten = ordered_tweet_tf_sentiments[-20:]
# tf_tweets = tf_bottom_ten + tf_top_ten
# tf_tweets = [{**original, 'method': 'transformers_pipeline'} for original in tf_tweets]
# tf_tweets

# ordered_tweet_sentiments = sorted(tweet_sentiments, key=itemgetter('score'))
# bottom_ten = ordered_tweet_sentiments[:20]
# top_ten = ordered_tweet_sentiments[-20:]
# textblob_tweets = bottom_ten + top_ten
# textblob_tweets = [{**original, 'method': 'textblob'} for original in textblob_tweets]
# textblob_tweets
# df = pd.DataFrame(tf_tweets + textblob_tweets)
# df
# df.to_csv("tweet_sentiments_by_method.csv")
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-14-8e20c3e6095e> in <module>
#       2 ordered_tweet_tf_sentiments = sorted(tweet_tf_sentiments, key=itemgetter('score'))
#       3 tf_sentiment_scores = [sentiment['score'] for sentiment in tweet_tf_sentiments]
# ----> 4 tf_overall_mean = mean(tf_sentiment_scores)
#       5 tf_overall_sd = stdev(tf_sentiment_scores)
#       6 tf_bottom_ten = ordered_tweet_tf_sentiments[:20]
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/statistics.py in mean(data)
#     308     n = len(data)
#     309     if n < 1:
# --> 310         raise StatisticsError('mean requires at least one data point')
#     311     T, total, count = _sum(data)
#     312     assert count == n
#
# StatisticsError: mean requires at least one data point

# %%
# Calculate the sentiment mean and standard deviation using textblob's results 
# as well as transformer pipeline's results
def get_family_sentiment_mean(family):
    if family not in family_tweet_sentiments:
        return math.nan
    polarity_mean, polarity_sd, num_tweets, tf_mean_polarity, tf_sd_polarity = family_tweet_sentiments[family]
    return polarity_mean

def get_family_sentiment_sd(family):
    if family not in family_tweet_sentiments:
        return math.nan
    polarity_mean, polarity_sd, num_tweets, tf_mean_polarity, tf_sd_polarity = family_tweet_sentiments[family]
    return polarity_sd

def get_family_sentiment_num_tweets(family):
    if family not in family_tweet_sentiments:
        return 0
    polarity_mean, polarity_sd, num_tweets, tf_mean_polarity, tf_sd_polarity = family_tweet_sentiments[family]
    return num_tweets

def get_tf_family_sentiment_mean(family):
    if family not in family_tweet_sentiments:
        return math.nan
    polarity_mean, polarity_sd, num_tweets, tf_mean_polarity, tf_sd_polarity = family_tweet_sentiments[family]
    return tf_mean_polarity

def get_tf_family_sentiment_sd(family):
    if family not in family_tweet_sentiments:
        return math.nan
    polarity_mean, polarity_sd, num_tweets, tf_mean_polarity, tf_sd_polarity = family_tweet_sentiments[family]
    return tf_sd_polarity

# %%
# Add sentiment results from the raw tweets csv to family results csv
results = pd.read_csv(TWITTER_RESULTS)
results['num_tweets_with_sentiment'] = results['family'].map(get_family_sentiment_num_tweets)
results['mean_sentiment_polarity'] = results['family'].map(get_family_sentiment_mean)
results['standard_deviation_sentiment_polarity'] = results['family'].map(get_family_sentiment_sd)
results['sentiment_analysis_transformer_mean'] = results['family'].map(get_tf_family_sentiment_mean)
results['sentiment_analysis_transformer_sd'] = results['family'].map(get_tf_family_sentiment_sd)
results
# results.to_csv("twitter_results_with_transformers_pipeline.csv")
# results.to_csv("twitter_results_with_sentiment.csv")
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  user_tweets_count  \
# 0             0             0               0               7196
# 1             1             1               1             151469
# 2             2             2               2                  0
# 3             3             3               3             375846
# 4             4             4               4              30854
# ..          ...           ...             ...                ...
# 869         869           869             872              34405
# 870         870           870             873               7198
# 871         871           871             874               1825
# 872         872           872             875             259175
# 873         873           873             876             385662
#
#      user_friends_count  user_followers_count  retweet_count  reply_count  \
# 0                  1048                 21575              2            0
# 1                  6487                 29757              1            9
# 2                     0                     0              0            0
# 3                  7042                  8119              1            4
# 4                  1232                   255              0            0
# ..                  ...                   ...            ...          ...
# 869                 598                 46471              0            1
# 870                   2                   136              0            0
# 871                 127                    62              0            1
# 872                3180                  9223              2            5
# 873               21044                 35326             33           23
#
#      quote_count  favorite_count            family  tweet_count  \
# 0              0              26     Archaeognatha            2
# 1              1              32        Blaberidae           15
# 2              0               0        Ectobiidae            0
# 3              0              10         Blattidae           12
# 4              0               0    Cryptocercidae            1
# ..           ...             ...               ...          ...
# 869            0               5      Lepismatidae            1
# 870            0               0      Nicoletiidae            1
# 871            0               1   Grylloblattidae            2
# 872            0              16  Mantophasmatodea            6
# 873            5             171      Strepsiptera           30
#
#      num_tweets_with_sentiment  mean_sentiment_polarity  \
# 0                            1                 0.000000
# 1                            3                 0.053333
# 2                            0                      NaN
# 3                            5                 0.125000
# 4                            0                      NaN
# ..                         ...                      ...
# 869                          0                      NaN
# 870                          1                 0.136364
# 871                          0                      NaN
# 872                          1                 0.000000
# 873                         26                 0.047578
#
#      standard_deviation_sentiment_polarity  \
# 0                                 0.000000
# 1                                 0.092376
# 2                                      NaN
# 3                                 0.233184
# 4                                      NaN
# ..                                     ...
# 869                                    NaN
# 870                               0.000000
# 871                                    NaN
# 872                               0.000000
# 873                               0.248334
#
#      sentiment_analysis_transformer_mean  sentiment_analysis_transformer_sd
# 0                              -0.930340                           0.000000
# 1                              -0.989438                           0.007005
# 2                                    NaN                                NaN
# 3                              -0.586738                           0.827855
# 4                                    NaN                                NaN
# ..                                   ...                                ...
# 869                                  NaN                                NaN
# 870                            -0.972827                           0.000000
# 871                                  NaN                                NaN
# 872                            -0.973013                           0.000000
# 873                            -0.651191                           0.720232
#
# [874 rows x 17 columns]

# %%
# Get the list of families into memory
families = []
with open(CLEANED_FAMILIES, 'r') as file:
    for line in file:
        families.append(line.split()[0])
families

# %%
# Fetch tweets from Twitter using their API and save to CSV
premium_search_args = load_credentials("credentials.yaml",
                                       yaml_key="search_tweets_api",
                                       env_overwrite=False)

header = False
for family in families:
    rule = gen_rule_payload("{family} -is:retweet".format(family=family), results_per_call=500)
    rs = ResultStream(rule_payload=rule,
                      max_results=500,
                      max_pages=0,
                      **premium_search_args)
    user_tweets_count = 0
    user_friends_count = 0
    user_followers_count = 0
    retweet_count = 0
    reply_count = 0
    quote_count = 0
    favorite_count = 0
    serialized_tweets = []
    for tweet in rs.stream():
        serialized_tweets.append(tweet)
        user_tweets_count += tweet['user']['statuses_count']
        user_friends_count += tweet.following_count
        user_followers_count += tweet.follower_count
        retweet_count += tweet.retweet_count
        reply_count += tweet['reply_count']
        quote_count += tweet.quote_count
        favorite_count += tweet.favorite_count
    row = {
        "user_tweets_count": user_tweets_count,
        "user_friends_count": user_friends_count,
        "user_followers_count": user_followers_count,
        "retweet_count": retweet_count,
        "reply_count": reply_count,
        "quote_count": quote_count,
        "favorite_count": favorite_count,
        "family": family
    }
    dump_row = {
        "serialized_tweets": json.dumps(serialized_tweets),
        "family": family
    }
    add_row(row, header=header)
    add_dump_row(dump_row, header=header)
    header = False 
    time.sleep(2)
